# %% [markdown]
# <a href="https://colab.research.google.com/github/wbfrench1/Getting_and_Cleaning_Data_Course_Project/blob/main/src/plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import date

# %%
t = np.arange(0,10,0.1)

x = np.sin(t)
y = np.sin(2*t)

vx = np.cos(t)
vy = 2*np.cos(2*t)

fig, ax = plt.subplots()
ax.plot(x, y)

# %%
fig, axs = plt.subplots(nrows=2, ncols=1,
                       sharex= True)

axs[0].plot(t, np.column_stack([x,y]), linewidth=2)
axs[1].plot(t, np.column_stack([vx,vy]), lw=2)

axs[0].set(ylabel='Position [m]')
axs[1].set(xlabel='Time [sec]', ylabel='Velocity [m/s]')

axs[0].set_xlim([0,10])

fig.text(0.8, 0.02, date.isoformat(date.today()))

for ax in axs:
    lines = ax.get_lines()
    lines[0].set_linestyle('--')

axs[0].legend(['x','y'])
